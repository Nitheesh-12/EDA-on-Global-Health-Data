# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv("G:\Project_1\countryData.csv")

# %%
df1.shape
# Out:
# (2938, 13)

# %%
df1.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing              65.0            263.0     0.01
# 1  Afghanistan  2014  Developing              59.9            271.0     0.01
# 2  Afghanistan  2013  Developing              59.9            268.0     0.01
# 3  Afghanistan  2012  Developing              59.5            272.0     0.01
# 4  Afghanistan  2011  Developing              59.2            275.0     0.01
#
#    Total expenditure         GDP  Population   thinness  1-19 years  \
# 0               8.16  584.259210  33736494.0                   17.2
# 1               8.18  612.696514    327582.0                   17.5
# 2               8.13  631.744976  31731688.0                   17.7
# 3               8.52  669.959000   3696958.0                   17.9
# 4               7.87   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   Alcohol                          2744 non-null   float64
#  6   Total expenditure                2712 non-null   float64
#  7   GDP                              2490 non-null   float64
#  8   Population                       2286 non-null   float64
#  9    thinness  1-19 years            2904 non-null   float64
#  10   thinness 5-9 years              2904 non-null   float64
# ...

# %%
cols=["Country","Year","Status","Life_expectancy","Adult_mortality","Alcohol","Total_expenditure","GDP","Population","Thinness_10_to_19_years",
      "Thinness_5_to_9_years","Income_composition_of_resources","Schooling"]

# %%
df1.columns=cols

# %%
df1.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_mortality                     10
# Alcohol                            194
# Total_expenditure                  226
# GDP                                448
# Population                         652
# Thinness_10_to_19_years             34
# Thinness_5_to_9_years               34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %%
df1.describe(include="all")
# Out:
#             Country         Year      Status  Life_expectancy  \
# count          2938  2938.000000        2938      2928.000000
# unique          193          NaN           2              NaN
# top     Afghanistan          NaN  Developing              NaN
# freq             16          NaN        2426              NaN
# mean            NaN  2007.518720         NaN        69.224932
# std             NaN     4.613841         NaN         9.523867
# min             NaN  2000.000000         NaN        36.300000
# 25%             NaN  2004.000000         NaN        63.100000
# 50%             NaN  2008.000000         NaN        72.100000
# 75%             NaN  2012.000000         NaN        75.700000
# max             NaN  2015.000000         NaN        89.000000
#
#         Adult_mortality      Alcohol  Total_expenditure            GDP  \
# count       2928.000000  2744.000000         2712.00000    2490.000000
# unique              NaN          NaN                NaN            NaN
# ...

# %%
sns.boxplot(df1.Life_expectancy)
# Out:
# <AxesSubplot: >

# %%
df1.Life_expectancy = df1.Life_expectancy.fillna(72.1)

# %%
sns.boxplot(df1.Adult_mortality)
# Out:
# <AxesSubplot: >

# %%
df1.Adult_mortality = df1.Adult_mortality.fillna(144.0)

# %%
sns.boxplot(df1.Alcohol)
# Out:
# <AxesSubplot: >

# %%
df1.Alcohol = df1.Alcohol.fillna(4.602861)

# %%
sns.boxplot(df1.Total_expenditure)
# Out:
# <AxesSubplot: >

# %%
df1.Total_expenditure = df1.Total_expenditure.fillna(5.75500)

# %%
sns.boxplot(df1.GDP)
# Out:
# <AxesSubplot: >

# %%
df1.GDP = df1.GDP.fillna(1766.947595)

# %%
sns.boxplot(df1.Population)
# Out:
# <AxesSubplot: >

# %%
df1.Population = df1.Population.fillna(1.386542e+06)

# %%
sns.boxplot(df1.Thinness_10_to_19_years)
# Out:
# <AxesSubplot: >

# %%
df1["Thinness_10_to_19_years"] = df1["Thinness_10_to_19_years"].fillna(3.300000)

# %%
sns.boxplot(df1["Thinness_5_to_9_years"])
# Out:
# <AxesSubplot: >

# %%
df1["Thinness_5_to_9_years"] = df1["Thinness_5_to_9_years"].fillna(3.300000)

# %%
sns.boxplot(df1.Income_composition_of_resources)
# Out:
# <AxesSubplot: >

# %%
df1.Income_composition_of_resources = df1.Income_composition_of_resources.fillna(0.677000)

# %%
sns.boxplot(df1.Schooling)
# Out:
# <AxesSubplot: >

# %%
df1.Schooling = df1.Schooling.fillna(12.300000)

# %%
df1.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life_expectancy                    0
# Adult_mortality                    0
# Alcohol                            0
# Total_expenditure                  0
# GDP                                0
# Population                         0
# Thinness_10_to_19_years            0
# Thinness_5_to_9_years              0
# Income_composition_of_resources    0
# Schooling                          0
# dtype: int64

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.describe(include="all")
# Out:
#             Country         Year      Status  Life_expectancy  \
# count          2938  2938.000000        2938      2938.000000
# unique          193          NaN           2              NaN
# top     Afghanistan          NaN  Developing              NaN
# freq             16          NaN        2426              NaN
# mean            NaN  2007.518720         NaN        69.234717
# std             NaN     4.613841         NaN         9.509115
# min             NaN  2000.000000         NaN        36.300000
# 25%             NaN  2004.000000         NaN        63.200000
# 50%             NaN  2008.000000         NaN        72.100000
# 75%             NaN  2012.000000         NaN        75.600000
# max             NaN  2015.000000         NaN        89.000000
#
#         Adult_mortality      Alcohol  Total_expenditure            GDP  \
# count       2938.000000  2938.000000        2938.000000    2938.000000
# unique              NaN          NaN                NaN            NaN
# ...

# %%
df2=pd.read_csv("G:\Project_1\immunitizationData.csv")

# %%
df2.shape
# Out:
# (2938, 10)

# %%
df2.head()
# Out:
#        Country  Year  infant deaths  Hepatitis B  Measles    BMI   \
# 0  Afghanistan  2015             62         65.0      1154   19.1
# 1  Afghanistan  2014             64         62.0       492   18.6
# 2  Afghanistan  2013             66         64.0       430   18.1
# 3  Afghanistan  2012             69         67.0      2787   17.6
# 4  Afghanistan  2011             71         68.0      3013   17.2
#
#    under-five deaths   Polio  Diphtheria    HIV/AIDS
# 0                  83    6.0         65.0        0.1
# 1                  86   58.0         62.0        0.1
# 2                  89   62.0         64.0        0.1
# 3                  93   67.0         67.0        0.1
# 4                  97   68.0         68.0        0.1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             2938 non-null   object
#  1   Year                2938 non-null   int64
#  2   infant deaths       2938 non-null   int64
#  3   Hepatitis B         2385 non-null   float64
#  4   Measles             2938 non-null   int64
#  5    BMI                2904 non-null   float64
#  6   under-five deaths   2938 non-null   int64
#  7   Polio               2919 non-null   float64
#  8   Diphtheria          2919 non-null   float64
#  9    HIV/AIDS           2938 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 229.7+ KB

# %%
cols=['Country','Year','Infant_deaths','Hepatitis_B','Measles','BMI','Under_5_deaths','Polio','Diphtheria','HIV/AIDS']

# %%
df2.columns=cols

# %%
df2.isna().sum()
# Out:
# Country             0
# Year                0
# Infant_deaths       0
# Hepatitis_B       553
# Measles             0
# BMI                34
# Under_5_deaths      0
# Polio              19
# Diphtheria         19
# HIV/AIDS            0
# dtype: int64

# %%
df2.describe(include="all")
# Out:
#             Country         Year  Infant_deaths  Hepatitis_B        Measles  \
# count          2938  2938.000000    2938.000000  2385.000000    2938.000000
# unique          193          NaN            NaN          NaN            NaN
# top     Afghanistan          NaN            NaN          NaN            NaN
# freq             16          NaN            NaN          NaN            NaN
# mean            NaN  2007.518720      30.303948    80.940461    2419.592240
# std             NaN     4.613841     117.926501    25.070016   11467.272489
# min             NaN  2000.000000       0.000000     1.000000       0.000000
# 25%             NaN  2004.000000       0.000000    77.000000       0.000000
# 50%             NaN  2008.000000       3.000000    92.000000      17.000000
# 75%             NaN  2012.000000      22.000000    97.000000     360.250000
# max             NaN  2015.000000    1800.000000    99.000000  212183.000000
#
# ...

# %%
sns.boxplot(df2['Hepatitis_B'])
# Out:
# <AxesSubplot: >

# %%
df2["Hepatitis_B"].fillna(92.000000,inplace=True)

# %%
sns.boxplot(df2.BMI)
# Out:
# <AxesSubplot: >

# %%
df2.BMI.fillna(38.321247,inplace=True)

# %%
sns.boxplot(df2.Polio)
# Out:
# <AxesSubplot: >

# %%
df2.Polio.fillna(93.000000,inplace=True)

# %%
sns.boxplot(df2.Diphtheria)
# Out:
# <AxesSubplot: >

# %%
df2.Diphtheria.fillna(93.000000,inplace=True)

# %%
df2.isna().sum()
# Out:
# Country           0
# Year              0
# Infant_deaths     0
# Hepatitis_B       0
# Measles           0
# BMI               0
# Under_5_deaths    0
# Polio             0
# Diphtheria        0
# HIV/AIDS          0
# dtype: int64

# %%
df2.describe(include="all")
# Out:
#             Country         Year  Infant_deaths  Hepatitis_B        Measles  \
# count          2938  2938.000000    2938.000000  2938.000000    2938.000000
# unique          193          NaN            NaN          NaN            NaN
# top     Afghanistan          NaN            NaN          NaN            NaN
# freq             16          NaN            NaN          NaN            NaN
# mean            NaN  2007.518720      30.303948    83.022124    2419.592240
# std             NaN     4.613841     117.926501    22.996984   11467.272489
# min             NaN  2000.000000       0.000000     1.000000       0.000000
# 25%             NaN  2004.000000       0.000000    82.000000       0.000000
# 50%             NaN  2008.000000       3.000000    92.000000      17.000000
# 75%             NaN  2012.000000      22.000000    96.000000     360.250000
# max             NaN  2015.000000    1800.000000    99.000000  212183.000000
#
# ...

# %%
df=pd.merge(df1,df2,on=["Country","Year"],how="outer")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2938 non-null   float64
#  4   Adult_mortality                  2938 non-null   float64
#  5   Alcohol                          2938 non-null   float64
#  6   Total_expenditure                2938 non-null   float64
#  7   GDP                              2938 non-null   float64
#  8   Population                       2938 non-null   float64
#  9   Thinness_10_to_19_years          2938 non-null   float64
#  10  Thinness_5_to_9_years            2938 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life_expectancy                    0
# Adult_mortality                    0
# Alcohol                            0
# Total_expenditure                  0
# GDP                                0
# Population                         0
# Thinness_10_to_19_years            0
# Thinness_5_to_9_years              0
# Income_composition_of_resources    0
# Schooling                          0
# Infant_deaths                      0
# Hepatitis_B                        0
# Measles                            0
# BMI                                0
# Under_5_deaths                     0
# Polio                              0
# Diphtheria                         0
# HIV/AIDS                           0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Life_expectancy  Adult_mortality      Alcohol  \
# count  2938.000000      2938.000000      2938.000000  2938.000000
# mean   2007.518720        69.234717       164.725664     4.602861
# std       4.613841         9.509115       124.086215     3.916288
# min    2000.000000        36.300000         1.000000     0.010000
# 25%    2004.000000        63.200000        74.000000     1.092500
# 50%    2008.000000        72.100000       144.000000     4.160000
# 75%    2012.000000        75.600000       227.000000     7.390000
# max    2015.000000        89.000000       723.000000    17.870000
#
#        Total_expenditure            GDP    Population  \
# count        2938.000000    2938.000000  2.938000e+03
# mean            5.924098    6611.523863  1.023085e+07
# std             2.400770   13296.603449  5.402242e+07
# min             0.370000       1.681350  3.400000e+01
# 25%             4.370000     580.486996  4.189172e+05
# ...

# %%
df[['Life_expectancy','Thinness_10_to_19_years','Thinness_5_to_9_years','Hepatitis_B','Measles','HIV/AIDS','Polio','Diphtheria','Adult_mortality',
    'Alcohol','Total_expenditure','GDP','Population','Income_composition_of_resources','Schooling','Under_5_deaths','BMI',
   'Infant_deaths']].corr(method='pearson')
# Out:
#                                  Life_expectancy  Thinness_10_to_19_years  \
# Life_expectancy                         1.000000                -0.468002
# Thinness_10_to_19_years                -0.468002                 1.000000
# Thinness_5_to_9_years                  -0.462473                 0.939187
# Hepatitis_B                             0.170219                -0.097576
# Measles                                -0.157767                 0.224870
# HIV/AIDS                               -0.556703                 0.203684
# Polio                                   0.458399                -0.218401
# Diphtheria                              0.472211                -0.226409
# Adult_mortality                        -0.696390                 0.296135
# Alcohol                                 0.390675                -0.414938
# Total_expenditure                       0.208844                -0.267572
# GDP                                     0.430461                -0.263323
# ...

# %%
df[["GDP","Life_expectancy"]].corr(method="pearson")
# Out:
#                       GDP  Life_expectancy
# GDP              1.000000         0.430461
# Life_expectancy  0.430461         1.000000

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=df,x="GDP",y="Life_expectancy",hue="Status")
plt.show()

# %%
df[["Income_composition_of_resources","Life_expectancy"]].corr(method="pearson")
# Out:
#                                  Income_composition_of_resources  \
# Income_composition_of_resources                         1.000000
# Life_expectancy                                         0.688662
#
#                                  Life_expectancy
# Income_composition_of_resources         0.688662
# Life_expectancy                         1.000000

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=df,x="Income_composition_of_resources",y="Life_expectancy",hue="Status")
plt.show()

# %%
df[["Schooling","Life_expectancy"]].corr(method="pearson")
# Out:
#                  Schooling  Life_expectancy
# Schooling         1.000000         0.713054
# Life_expectancy   0.713054         1.000000

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=df,x="Schooling",y="Life_expectancy",hue="Status")
plt.show()

# %%
df[['Thinness_10_to_19_years','Thinness_5_to_9_years','Hepatitis_B','Measles','HIV/AIDS','Polio','Diphtheria','Life_expectancy']].corr(method='pearson')
# Out:
#                          Thinness_10_to_19_years  Thinness_5_to_9_years  \
# Thinness_10_to_19_years                 1.000000               0.939187
# Thinness_5_to_9_years                   0.939187               1.000000
# Hepatitis_B                            -0.097576              -0.100576
# Measles                                 0.224870               0.221138
# HIV/AIDS                                0.203684               0.206899
# Polio                                  -0.218401              -0.219168
# Diphtheria                             -0.226409              -0.219699
# Life_expectancy                        -0.468002              -0.462473
#
#                          Hepatitis_B   Measles  HIV/AIDS     Polio  \
# Thinness_10_to_19_years    -0.097576  0.224870  0.203684 -0.218401
# Thinness_5_to_9_years      -0.100576  0.221138  0.206899 -0.219168
# Hepatitis_B                 1.000000 -0.073021 -0.085497  0.364890
# ...

# %%
df[['Hepatitis_B','Polio',"Diphtheria",'Life_expectancy']].corr(method="pearson")
# Out:
#                  Hepatitis_B     Polio  Diphtheria  Life_expectancy
# Hepatitis_B         1.000000  0.364890    0.449151         0.170219
# Polio               0.364890  1.000000    0.673977         0.458399
# Diphtheria          0.449151  0.673977    1.000000         0.472211
# Life_expectancy     0.170219  0.458399    0.472211         1.000000

# %%
df[['Adult_mortality','Infant_deaths','Life_expectancy']].corr(method="pearson")
# Out:
#                  Adult_mortality  Infant_deaths  Life_expectancy
# Adult_mortality          1.00000       0.078890        -0.696390
# Infant_deaths            0.07889       1.000000        -0.196769
# Life_expectancy         -0.69639      -0.196769         1.000000

# %%
df[['GDP','Life_expectancy','Schooling']].corr(method="pearson")
# Out:
#                       GDP  Life_expectancy  Schooling
# GDP              1.000000         0.430461   0.432229
# Life_expectancy  0.430461         1.000000   0.713054
# Schooling        0.432229         0.713054   1.000000

# %%
avg_life_exp_by_country=df.groupby(['Country'])["Life_expectancy"].mean()

# %%
avg_life_exp_by_country.sort_values(ascending=False).head()
# Out:
# Country
# Japan          82.53750
# Sweden         82.51875
# Iceland        82.44375
# Switzerland    82.33125
# France         82.21875
# Name: Life_expectancy, dtype: float64

# %%
avg_life_exp_by_country.sort_values(ascending=False).tail()
# Out:
# Country
# Malawi                      49.89375
# Angola                      49.01875
# Lesotho                     48.78125
# Central African Republic    48.51250
# Sierra Leone                46.11250
# Name: Life_expectancy, dtype: float64

# %%
avg_life_exp_by_country.rank().sort_values()
# Out:
# Country
# Sierra Leone                  1.0
# Central African Republic      2.0
# Lesotho                       3.0
# Angola                        4.0
# Malawi                        5.0
#                             ...
# France                      189.0
# Switzerland                 190.0
# Iceland                     191.0
# Sweden                      192.0
# Japan                       193.0
# Name: Life_expectancy, Length: 193, dtype: float64

# %%
developed = df[df['Status'] == 'Developed']
developing = df[df['Status'] == 'Developing']
plt.figure(figsize=(5,3))
sns.scatterplot(data=df,x="Life_expectancy",y="Status",hue="Status")
plt.title('Mean Life Expectancy by Status')
plt.show()

# %%
countries=['India','United States of America','China','Central African Republic','Bhutan']
df_country = df[df['Country'].isin(countries)]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df_country,x="Country",y="Life_expectancy")
plt.title('Distribution of Life Expectancy by Country')
plt.xlabel('Country')
plt.ylabel('Life Expectancy')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_country, x='GDP', y='Life_expectancy', hue='Country')
plt.title('Correlation between Life Expectancy and GDP per Capita by Country')
plt.xlabel('GDP per capita')
plt.ylabel('Life Expectancy')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_country, x='Schooling', y='Life_expectancy', hue='Country')
plt.title('Correlation between Life Expectancy and Schooling by Country')
plt.xlabel('Schooling')
plt.ylabel('Life Expectancy')
plt.show()

# %%
x=df.groupby("Country").agg({'Life_expectancy':'mean','Total_expenditure':'mean','BMI':'mean','Alcohol':'mean','Population':'mean'})

# %%
x1=x[x.Life_expectancy<65]
x1[['Life_expectancy','Total_expenditure']].corr(method="pearson")
# Out:
#                    Life_expectancy  Total_expenditure
# Life_expectancy            1.00000           -0.39608
# Total_expenditure         -0.39608            1.00000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=x1, x='Life_expectancy', y='Total_expenditure')
plt.title('Correlation between Life Expectancy and Total expenditure by Country')
plt.ylabel('Total_expenditure')
plt.xlabel('Life Expectancy')
plt.show()

# %%
x[['Life_expectancy','BMI','Alcohol']].corr(method="pearson")
# Out:
#                  Life_expectancy       BMI   Alcohol
# Life_expectancy         1.000000  0.655004  0.427056
# BMI                     0.655004  1.000000  0.287256
# Alcohol                 0.427056  0.287256  1.000000

# %%
x[['Population','Life_expectancy']].corr()
# Out:
#                  Population  Life_expectancy
# Population         1.000000        -0.055641
# Life_expectancy   -0.055641         1.000000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=x, x='Life_expectancy', y='Population')
plt.title('Correlation between Life Expectancy and Population by Country')
plt.ylabel('Population')
plt.xlabel('Life Expectancy')
plt.show()

# %%
y=df.groupby("Life_expectancy").agg({'Life_expectancy':'mean','Total_expenditure':'mean','BMI':'mean','Alcohol':'mean','Population':'mean'})

# %%
y1=y[y.Life_expectancy<65]
y1[['Life_expectancy','Total_expenditure']].corr(method="pearson")
# Out:
#                    Life_expectancy  Total_expenditure
# Life_expectancy           1.000000          -0.388852
# Total_expenditure        -0.388852           1.000000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=y1, x='Life_expectancy', y='Total_expenditure')
plt.title('Correlation between Life Expectancy and Total expenditure by Country')
plt.ylabel('Total_expenditure')
plt.xlabel('Life Expectancy')
plt.show()

# %%
y[['Life_expectancy','BMI','Alcohol']].corr(method="pearson")
# Out:
#                  Life_expectancy       BMI   Alcohol
# Life_expectancy         1.000000  0.858821  0.548711
# BMI                     0.858821  1.000000  0.621264
# Alcohol                 0.548711  0.621264  1.000000

# %%
country=["India","China","United States of America"]
y1=df[df['Country'].isin(country)]

# %%
y1[["Population","Life_expectancy"]].corr(method="pearson")
# Out:
#                  Population  Life_expectancy
# Population         1.000000        -0.514095
# Life_expectancy   -0.514095         1.000000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=y1, x='Population', y='Life_expectancy',hue="Country")
plt.title('Correlation between Life Expectancy and Population by Country')
plt.ylabel('Population')
plt.xlabel('Life Expectancy')
plt.show()
